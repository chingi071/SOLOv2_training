# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
#! git clone https://github.com/WXinlong/SOLO.git
# %cd SOLO
# Out:
# /content/drive/MyDrive/SOLO

# %%
! pip install -r requirements/build.txt
! pip install "git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI"
! pip install -v -e .  # or "python setup.py develop"

# %%
! mkdir data

# %%
# 然後將剛剛轉換好的資料放至 data 資料夾中

# %%
# 在 mmdet/datasets 裡創建自定義數據集 -- my_dataset.py

# %%
# 在 mmdet/datasets/__init__.py 加入剛剛定義好的數據集
# from .my_dataset import MyDataset
# __all__ = [] 加入 'MyDataset'

# %%
# 修改 configs/solov2/solov2_light_448_r18_fpn_8gpu_3x.py

# 更改第20行: num_classes 設定為類別數+1
# 更改第59、60行: dataset_type 和 data_root 路徑
# 更改第97、98、102、103、107、108行: data = dict() 裡 train、val、test 的 ann_file、img_prefix 路徑
# 可修改 optimizer、learning rate、total_epochs 等超參數，其中 work_dir 為存放訓練模型的路徑

# %%
! python tools/train.py configs/solov2/solov2_light_448_r18_fpn_8gpu_3x.py
# Out:
# 2021-10-24 12:58:31,183 - mmdet - INFO - Distributed training: False
# 2021-10-24 12:58:31,184 - mmdet - INFO - MMDetection Version: 1.0.0+95f3732
# 2021-10-24 12:58:31,184 - mmdet - INFO - Config:
# # model settings
# model = dict(
#     type='SOLOv2',
#     pretrained='torchvision://resnet18',
#     backbone=dict(
#         type='ResNet',
#         depth=18,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3), # C2, C3, C4, C5
#         frozen_stages=1,
#         style='pytorch'),
#     neck=dict(
#         type='FPN',
#         in_channels=[64, 128, 256, 512],
#         out_channels=256,
#         start_level=0,
#         num_outs=5),
#     bbox_head=dict(
#         type='SOLOv2Head',
#         num_classes=3,
#         in_channels=256,
#         stacked_convs=2,
#         seg_feat_channels=256,
#         strides=[8, 8, 16, 32, 32],
#         scale_ranges=((1, 56), (28, 112), (56, 224), (112, 448), (224, 896)),
#         sigma=0.2,
#         num_grids=[40, 36, 24, 16, 12],
# ...

# %%
# 修改 tools/test_ins_vis.py vis_seg 函數 class_names = ['background', 'raccoon']

# %%
! python tools/test_ins_vis.py configs/solov2/solov2_light_448_r18_fpn_8gpu_3x.py weights/solov2_light_release_r18_fpn_8gpu_3x/latest.pth --show --save_dir work_dirs/vis_solo
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# terminal width is too small (0), please consider widen the terminal for better progressbar visualization
# [          ] 0/10, elapsed: 0s, ETA:/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3613: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# ...

# %%
! python tools/test_ins.py configs/solov2/solov2_light_448_r18_fpn_8gpu_3x.py weights/solov2_light_release_r18_fpn_8gpu_3x/latest.pth --show --out results_solo.pkl --eval segm
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# terminal width is too small (0), please consider widen the terminal for better progressbar visualization
# [          ] 0/10, elapsed: 0s, ETA:/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3613: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# ...

# %%
# 修改 demo/inference_demo.py
# config_file = 'configs/solov2/solov2_light_448_r18_fpn_8gpu_3x.py'
# checkpoint_file = 'weights/solov2_light_release_r18_fpn_8gpu_3x/latest.pth'
# img = 'demo/test.jpg'
# out_file="demo/demo_out.jpg"

# %%
! python demo/inference_demo.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3613: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# ...
